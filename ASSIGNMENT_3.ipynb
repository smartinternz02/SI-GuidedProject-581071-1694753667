# %% [markdown]
# Assignment_3
#
# DONE BY-ABDUL AZIZ 21BCE8621
#
# Penguin Classification Analysis
#
# Problem Statement:
#
# The Penguin Classification Analysis problem involves predicting the species of a penguin
# based on various physical characteristics. The dataset includes information about the body
# mass, culmen length, culmen depth, flipper length, and sex of different penguin species.
# The problem is typically approached as a classification problem, where the target variable is
# the penguin species, and the features are the physical characteristics of the penguins.
#
# Accurate classification of penguin species can also help researchers understand the effects of climate change and other environmental factors on penguin populations. The problem can also be useful for conservation efforts, as it can help identify and protect endangered penguin
# species.
#
# Attribute Information:
#
# ● Species: penguin species (Chinstrap, Adélie, or Gentoo)
#
# ● Island: island name (Dream, Torgersen, or Biscoe) in Antarctica
#
# ● culmen_length_mm: culmen length (mm)
#
# ● culmen_depth_mm: culmen depth (mm)
#
# ● flipper_length_mm: flipper length (mm)
#
# ● body_mass_g: body mass (g)
#
# ● Sex: penguin sex
#
# Clustering the data and performing classification algorithms
# 1. Download the dataset: Dataset
# 2. Load the dataset into the tool.
# 3. Perform Below Visualizations.
# ● Univariate Analysis
# ● Bi- Variate Analysis
# ● Multi-Variate Analysis
# 4. Perform descriptive statistics on the dataset.
# 5. Check for Missing values and deal with them.
# 6. Find the outliers and replace them outliers
# 7. Check the correlation of independent variables with the target
# 8. Check for Categorical columns and perform encoding.
# 9. Split the data into dependent and independent variables.
# 10. Scaling the data
# 11. Split the data into training and testing
# 12. check the training and testing data shape

# %%
#TASK 1: DATASET[penguins_size.CSV]

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#TASK 2: LOAD THE DATASET
df = pd.read_csv('/content/penguins_size.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
#TASK_3 Univariate Analysis:
sns.countplot(df['body_mass_g'])
df['body_mass_g'].value_counts().plot(kind='bar')
# Out:
# <Axes: ylabel='count'>

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='sex'>

# %%
plt.hist(df['body_mass_g'], bins=10)
plt.xlabel('body mass')
plt.ylabel('No of penguins')
plt.title('Histogram')
plt.show()

# %%
sns.displot(df['body_mass_g'], kde=True)
plt.xlabel('body mass')
plt.ylabel('no.of penguins')
plt.title('Distplot')
plt.show()

# %%
sns.boxplot(x='body_mass_g', data=df)
plt.xlabel('X-axis label')
plt.title('Boxplot')
plt.show()

# %%
#Bi- Variate Analysis
#boxplot
sns.boxplot(x='species',y='culmen_depth_mm',data=df)
plt.show()

# %%
#Bi- Variate Analysis
#boxplot
sns.boxplot(x='culmen_length_mm',y='culmen_depth_mm',data=df)
plt.show()

# %%
#barplot
sns.barplot(x='species',y='flipper_length_mm',data=df)
plt.show()

# %%
#stripplot
sns.stripplot(x='species',y='flipper_length_mm',data=df)
plt.show()

# %%
#distplot
sns.displot(x='species',y='culmen_depth_mm',data=df)
plt.show()

# %%
#Multivariate Analysis
sns.heatmap(pd.crosstab(df['species'],df['culmen_length_mm']))
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='species'>

# %%
(df.groupby('island').mean()['culmen_depth_mm']).plot(kind='bar')
# Out:
# <ipython-input-16-a97c55a98894>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (df.groupby('island').mean()['culmen_depth_mm']).plot(kind='bar')
# <Axes: xlabel='island'>

# %%
#clustermap
sns.clustermap(pd.crosstab(df['species'],df['sex']))

# %%
#clustermap
sns.clustermap(pd.crosstab(df['species'],df['culmen_depth_mm']))

# %%
#clustermap
sns.clustermap(pd.crosstab(df['sex'],df['species']))

# %%
sns.pairplot(df)
plt.show()

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
#Task_4 Perform descriptive statistics on the dataset.
# Descriptive statistics for the entire dataset
descriptive_stats = df.describe()
print(descriptive_stats)
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df['body_mass_g'].value_counts()
# Out:
# 3800.0    12
# 3700.0    11
# 3900.0    10
# 3950.0    10
# 3550.0     9
#           ..
# 4475.0     1
# 3975.0     1
# 3575.0     1
# 3850.0     1
# 5750.0     1
# Name: body_mass_g, Length: 94, dtype: int64

# %%
df['body_mass_g'].value_counts().to_frame()
# Out:
#         body_mass_g
# 3800.0           12
# 3700.0           11
# 3900.0           10
# 3950.0           10
# 3550.0            9
# ...             ...
# 4475.0            1
# 3975.0            1
# 3575.0            1
# 3850.0            1
# 5750.0            1
#
# [94 rows x 1 columns]

# %%
#Task-5 Remove rows with missing values
df = df.dropna()

# %%
# Impute missing values with the mean of the respective column
df['body_mass_g'] = df['culmen_length_mm'].fillna(df['culmen_depth_mm'].mean())

# %%
# Interpolate missing values
df['body_mass_g'] = df['culmen_length_mm'].interpolate()
df
# Out:
# <ipython-input-28-77571bd7d549>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['body_mass_g'] = df['culmen_length_mm'].interpolate()
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# ...

# %%
#Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
# Fill missing values with the mean of the respective column
df.fillna(df.mean(), inplace=True)
df.head()
# Out:
# <ipython-input-30-54dae2c70107>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)
# <ipython-input-30-54dae2c70107>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(df.mean(), inplace=True)
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# ...

# %%
# Impute missing values with the mean of the column
df_filled = df.fillna(df.mean())
df
# Out:
# <ipython-input-31-e72a3e098a94>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_filled = df.fillna(df.mean())
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# ...

# %%
df.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 4      False   False             False            False              False
# 5      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 338    False   False             False            False              False
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# Replace all 0's with -1 in the entire DataFrame
df = df.replace(0, -1)
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
q1=df.culmen_length_mm.quantile(0.25)
q2=df.culmen_length_mm.quantile(0.75)

# %%
print(q1)
print(q2)
# Out:
# 39.5
# 48.575

# %%
IQR=q2-q1

# %%
IQR
# Out:
# 9.075000000000003

# %%
upper_limit=q2+1.5*IQR

# %%
upper_limit
# Out:
# 62.18750000000001

# %%
lower_limit=q2-1.5*IQR
lower_limit
# Out:
# 34.9625

# %%
df=df[df.culmen_length_mm<upper_limit]

# %%
df.median()
# Out:
# <ipython-input-44-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# culmen_length_mm      44.5
# culmen_depth_mm       17.3
# flipper_length_mm    197.0
# body_mass_g           44.5
# dtype: float64

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
from scipy import stats

# %%
culmen_length_zscore=stats.zscore(df.culmen_length_mm)
culmen_length_zscore
# Out:
# 0     -0.897653
# 1     -0.824290
# 2     -0.677564
# 4     -1.337831
# 5     -0.860972
#          ...
# 338    0.587947
# 340    0.514584
# 341    1.174851
# 342    0.221132
# 343    1.083147
# Name: culmen_length_mm, Length: 334, dtype: float64

# %%
#LABEL ENCODING
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
le=LabelEncoder()
df.sex=le.fit_transform(df.sex)
df.smoker=le.fit_transform(df.island)
df.head
# Out:
# <ipython-input-50-fc526515df7b>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.smoker=le.fit_transform(df.island)
# <bound method NDFrame.head of     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# ...

# %%
df_main=df
df_main.corr().body_mass_g.sort_values(ascending=False)
# Out:
# <ipython-input-51-15f0b8a12a8c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_main.corr().body_mass_g.sort_values(ascending=False)
# culmen_length_mm     1.000000
# body_mass_g          1.000000
# flipper_length_mm    0.652126
# sex                  0.338676
# culmen_depth_mm     -0.228640
# Name: body_mass_g, dtype: float64

# %%
#independent and dependent variables
y=df_main['island']
y
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 334, dtype: object

# %%
#Check for Categorical columns and perform encoding.
dataset=pd.read_csv('/content/penguins_size.csv',delimiter=';')

# %%
df=dataset.tail(10)
df
# Out:
#     species,island,culmen_length_mm,culmen_depth_mm,flipper_length_mm,body_mass_g,sex
# 334            Gentoo,Biscoe,46.2,14.1,217,4375,FEMALE
# 335                Gentoo,Biscoe,55.1,16,230,5850,MALE
# 336                 Gentoo,Biscoe,44.5,15.7,217,4875,.
# 337              Gentoo,Biscoe,48.8,16.2,222,6000,MALE
# 338            Gentoo,Biscoe,47.2,13.7,214,4925,FEMALE
# 339                       Gentoo,Biscoe,NA,NA,NA,NA,NA
# 340            Gentoo,Biscoe,46.8,14.3,215,4850,FEMALE
# 341              Gentoo,Biscoe,50.4,15.7,222,5750,MALE
# 342            Gentoo,Biscoe,45.2,14.8,212,5200,FEMALE
# 343              Gentoo,Biscoe,49.9,16.1,213,5400,MALE

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=df.iloc[:,:].values

# %%
df
# Out:
# array([['Gentoo,Biscoe,46.2,14.1,217,4375,FEMALE'],
#        ['Gentoo,Biscoe,55.1,16,230,5850,MALE'],
#        ['Gentoo,Biscoe,44.5,15.7,217,4875,.'],
#        ['Gentoo,Biscoe,48.8,16.2,222,6000,MALE'],
#        ['Gentoo,Biscoe,47.2,13.7,214,4925,FEMALE'],
#        ['Gentoo,Biscoe,NA,NA,NA,NA,NA'],
#        ['Gentoo,Biscoe,46.8,14.3,215,4850,FEMALE'],
#        ['Gentoo,Biscoe,50.4,15.7,222,5750,MALE'],
#        ['Gentoo,Biscoe,45.2,14.8,212,5200,FEMALE'],
#        ['Gentoo,Biscoe,49.9,16.1,213,5400,MALE']], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
country=LabelEncoder()

# %%
df[:,0]=country.fit_transform(df[:,0])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct=ColumnTransformer(transformers=[('encode',OneHotEncoder(),[8])],remainder='passthrough')

# %%
y
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 334, dtype: object

# %%
y=pd.DataFrame(y)
y
# Out:
#         island
# 0    Torgersen
# 1    Torgersen
# 2    Torgersen
# 4    Torgersen
# 5    Torgersen
# ..         ...
# 338     Biscoe
# 340     Biscoe
# 341     Biscoe
# 342     Biscoe
# 343     Biscoe
#
# [334 rows x 1 columns]

# %%
df
# Out:
# array([[2],
#        [8],
#        [0],
#        [5],
#        [4],
#        [9],
#        [3],
#        [7],
#        [1],
#        [6]], dtype=object)

# %%
#Split the data into dependent and independent variables.
df=pd.read_csv('/content/penguins_size.csv')

# %%
x=df.iloc[:,1:4]

# %%
y=df.iloc[:,4]

# %%
#Scaling the data
from sklearn.preprocessing import StandardScaler
data=pd.read_csv('/content/penguins_size.csv')
print(data)
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
cname=data.columns[:-1]
scale=StandardScaler()
print(data)
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
#Split the data into training and testing
X = df[['culmen_length_mm','culmen_depth_mm']]

# %%
y = df['flipper_length_mm']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#      culmen_length_mm  culmen_depth_mm
# 106              38.6             17.2
# 201              49.8             17.3
# 324              47.3             13.8
# 315              50.8             15.7
# 215              55.8             19.8
# ..                ...              ...
# 204              45.7             17.3
# 255              48.4             16.3
# 299              45.2             16.4
# 95               40.8             18.9
# 25               35.3             18.9
#
# [240 rows x 2 columns]

# %%
X_test
# Out:
#      culmen_length_mm  culmen_depth_mm
# 125              40.6             19.0
# 222              48.7             14.1
# 292              48.2             15.6
# 318              48.4             14.4
# 165              52.0             18.1
# ..                ...              ...
# 34               36.4             17.0
# 224              47.6             14.5
# 116              38.6             17.0
# 173              48.5             17.5
# 93               39.6             18.1
#
# [104 rows x 2 columns]

# %%
#check the training and testing data shape.
y_train
# Out:
# 106    199.0
# 201    198.0
# 324    216.0
# 315    226.0
# 215    207.0
#        ...
# 204    193.0
# 255    220.0
# 299    223.0
# 95     208.0
# 25     187.0
# Name: flipper_length_mm, Length: 240, dtype: float64

# %%
y_test
# Out:
# 125    199.0
# 222    210.0
# 292    221.0
# 318    203.0
# 165    201.0
#        ...
# 34     195.0
# 224    215.0
# 116    188.0
# 173    191.0
# 93     186.0
# Name: flipper_length_mm, Length: 104, dtype: float64
